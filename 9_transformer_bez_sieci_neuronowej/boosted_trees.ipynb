# %%
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Load MNIST data
mnist = fetch_openml('mnist_784', version=1)
X, y = mnist["data"], mnist["target"].astype(np.uint8)

# Filter for images of the digit 5
X_5 = X[y == 5]

# Split data for a small experiment (to reduce computational load)
# In practice, you'd use much more data
X_train_5, X_test_5 = train_test_split(X_5, test_size=0.95, random_state=42)

# %%
# Standardize features by removing the mean and scaling to unit variance
scaler = StandardScaler()
X_train_5_scaled = scaler.fit_transform(X_train_5)

# Train a model for each pixel
models = []
for i in range(X_train_5.shape[1]):  # For each pixel
    print(f"Training model for pixel {i+1}/{X_train_5.shape[1]}")
    y_train = X_train_5_scaled[:, i]
    X_train = np.delete(X_train_5_scaled, i, axis=1)  # Use all other pixels as features
    model = XGBRegressor(objective='reg:squarederror', n_estimators=6)  # Simplified model
    model.fit(X_train, y_train)
    models.append(model)
# Out:
# Training model for pixel 1/784
# Training model for pixel 2/784
# Training model for pixel 3/784
# Training model for pixel 4/784
# Training model for pixel 5/784
# Training model for pixel 6/784
# Training model for pixel 7/784
# Training model for pixel 8/784
# Training model for pixel 9/784
# Training model for pixel 10/784
# Training model for pixel 11/784
# Training model for pixel 12/784
# Training model for pixel 13/784
# Training model for pixel 14/784
# Training model for pixel 15/784
# Training model for pixel 16/784
# Training model for pixel 17/784
# Training model for pixel 18/784
# Training model for pixel 19/784
# Training model for pixel 20/784
# Training model for pixel 21/784
# Training model for pixel 22/784
# Training model for pixel 23/784
# Training model for pixel 24/784
# Training model for pixel 25/784
# Training model for pixel 26/784
# Training model for pixel 27/784
# Training model for pixel 28/784
# Training model for pixel 29/784
# Training model for pixel 30/784
# Training model for pixel 31/784
# Training model for pixel 32/784
# Training model for pixel 33/784
# Training model for pixel 34/784
# Training model for pixel 35/784
# Training model for pixel 36/784
# Training model for pixel 37/784
# Training model for pixel 38/784
# Training model for pixel 39/784
# Training model for pixel 40/784
# Training model for pixel 41/784
# Training model for pixel 42/784
# Training model for pixel 43/784
# Training model for pixel 44/784
# Training model for pixel 45/784
# Training model for pixel 46/784
# Training model for pixel 47/784
# Training model for pixel 48/784
# Training model for pixel 49/784
# Training model for pixel 50/784
# Training model for pixel 51/784
# Training model for pixel 52/784
# Training model for pixel 53/784
# Training model for pixel 54/784
# Training model for pixel 55/784
# Training model for pixel 56/784
# Training model for pixel 57/784
# Training model for pixel 58/784
# Training model for pixel 59/784
# Training model for pixel 60/784
# Training model for pixel 61/784
# Training model for pixel 62/784
# Training model for pixel 63/784
# Training model for pixel 64/784
# Training model for pixel 65/784
# Training model for pixel 66/784
# Training model for pixel 67/784
# Training model for pixel 68/784
# Training model for pixel 69/784
# Training model for pixel 70/784
# Training model for pixel 71/784
# Training model for pixel 72/784
# Training model for pixel 73/784
# Training model for pixel 74/784
# Training model for pixel 75/784
# Training model for pixel 76/784
# Training model for pixel 77/784
# Training model for pixel 78/784
# Training model for pixel 79/784
# Training model for pixel 80/784
# Training model for pixel 81/784
# Training model for pixel 82/784
# Training model for pixel 83/784
# Training model for pixel 84/784
# Training model for pixel 85/784
# Training model for pixel 86/784
# Training model for pixel 87/784
# Training model for pixel 88/784
# Training model for pixel 89/784
# Training model for pixel 90/784
# Training model for pixel 91/784
# Training model for pixel 92/784
# Training model for pixel 93/784
# Training model for pixel 94/784
# Training model for pixel 95/784
# Training model for pixel 96/784
# Training model for pixel 97/784
# Training model for pixel 98/784
# Training model for pixel 99/784
# Training model for pixel 100/784
# Training model for pixel 101/784
# Training model for pixel 102/784
# Training model for pixel 103/784
# Training model for pixel 104/784
# Training model for pixel 105/784
# Training model for pixel 106/784
# Training model for pixel 107/784
# Training model for pixel 108/784
# Training model for pixel 109/784
# Training model for pixel 110/784
# Training model for pixel 111/784
# Training model for pixel 112/784
# Training model for pixel 113/784
# Training model for pixel 114/784
# Training model for pixel 115/784
# Training model for pixel 116/784
# Training model for pixel 117/784
# Training model for pixel 118/784
# Training model for pixel 119/784
# Training model for pixel 120/784
# Training model for pixel 121/784
# Training model for pixel 122/784
# Training model for pixel 123/784
# Training model for pixel 124/784
# Training model for pixel 125/784
# Training model for pixel 126/784
# Training model for pixel 127/784
# Training model for pixel 128/784
# Training model for pixel 129/784
# Training model for pixel 130/784
# Training model for pixel 131/784
# Training model for pixel 132/784
# Training model for pixel 133/784
# Training model for pixel 134/784
# Training model for pixel 135/784
# Training model for pixel 136/784
# Training model for pixel 137/784
# Training model for pixel 138/784
# Training model for pixel 139/784
# Training model for pixel 140/784
# Training model for pixel 141/784
# Training model for pixel 142/784
# Training model for pixel 143/784
# Training model for pixel 144/784
# Training model for pixel 145/784
# Training model for pixel 146/784
# Training model for pixel 147/784
# Training model for pixel 148/784
# Training model for pixel 149/784
# Training model for pixel 150/784
# Training model for pixel 151/784
# Training model for pixel 152/784
# Training model for pixel 153/784
# Training model for pixel 154/784
# Training model for pixel 155/784
# Training model for pixel 156/784
# Training model for pixel 157/784
# Training model for pixel 158/784
# Training model for pixel 159/784
# Training model for pixel 160/784
# Training model for pixel 161/784
# Training model for pixel 162/784
# Training model for pixel 163/784
# Training model for pixel 164/784
# Training model for pixel 165/784
# Training model for pixel 166/784
# Training model for pixel 167/784
# Training model for pixel 168/784
# Training model for pixel 169/784
# Training model for pixel 170/784
# Training model for pixel 171/784
# Training model for pixel 172/784
# Training model for pixel 173/784
# Training model for pixel 174/784
# Training model for pixel 175/784
# Training model for pixel 176/784
# Training model for pixel 177/784
# Training model for pixel 178/784
# Training model for pixel 179/784
# Training model for pixel 180/784
# Training model for pixel 181/784
# Training model for pixel 182/784
# Training model for pixel 183/784
# Training model for pixel 184/784
# Training model for pixel 185/784
# Training model for pixel 186/784
# Training model for pixel 187/784
# Training model for pixel 188/784
# Training model for pixel 189/784
# Training model for pixel 190/784
# Training model for pixel 191/784
# Training model for pixel 192/784
# Training model for pixel 193/784
# Training model for pixel 194/784
# Training model for pixel 195/784
# Training model for pixel 196/784
# Training model for pixel 197/784
# Training model for pixel 198/784
# Training model for pixel 199/784
# Training model for pixel 200/784
# Training model for pixel 201/784
# Training model for pixel 202/784
# Training model for pixel 203/784
# Training model for pixel 204/784
# Training model for pixel 205/784
# Training model for pixel 206/784
# Training model for pixel 207/784
# Training model for pixel 208/784
# Training model for pixel 209/784
# Training model for pixel 210/784
# Training model for pixel 211/784
# Training model for pixel 212/784
# Training model for pixel 213/784
# Training model for pixel 214/784
# Training model for pixel 215/784
# Training model for pixel 216/784
# Training model for pixel 217/784
# Training model for pixel 218/784
# Training model for pixel 219/784
# Training model for pixel 220/784
# Training model for pixel 221/784
# Training model for pixel 222/784
# Training model for pixel 223/784
# Training model for pixel 224/784
# Training model for pixel 225/784
# Training model for pixel 226/784
# Training model for pixel 227/784
# Training model for pixel 228/784
# Training model for pixel 229/784
# Training model for pixel 230/784
# Training model for pixel 231/784
# Training model for pixel 232/784
# Training model for pixel 233/784
# Training model for pixel 234/784
# Training model for pixel 235/784
# Training model for pixel 236/784
# Training model for pixel 237/784
# Training model for pixel 238/784
# Training model for pixel 239/784
# Training model for pixel 240/784
# Training model for pixel 241/784
# Training model for pixel 242/784
# Training model for pixel 243/784
# Training model for pixel 244/784
# Training model for pixel 245/784
# Training model for pixel 246/784
# Training model for pixel 247/784
# Training model for pixel 248/784
# Training model for pixel 249/784
# Training model for pixel 250/784
# Training model for pixel 251/784
# Training model for pixel 252/784
# Training model for pixel 253/784
# Training model for pixel 254/784
# Training model for pixel 255/784
# Training model for pixel 256/784
# Training model for pixel 257/784
# Training model for pixel 258/784
# Training model for pixel 259/784
# Training model for pixel 260/784
# Training model for pixel 261/784
# Training model for pixel 262/784
# Training model for pixel 263/784
# Training model for pixel 264/784
# Training model for pixel 265/784
# Training model for pixel 266/784
# Training model for pixel 267/784
# Training model for pixel 268/784
# Training model for pixel 269/784
# Training model for pixel 270/784
# Training model for pixel 271/784
# Training model for pixel 272/784
# Training model for pixel 273/784
# Training model for pixel 274/784
# Training model for pixel 275/784
# Training model for pixel 276/784
# Training model for pixel 277/784
# Training model for pixel 278/784
# Training model for pixel 279/784
# Training model for pixel 280/784
# Training model for pixel 281/784
# Training model for pixel 282/784
# Training model for pixel 283/784
# Training model for pixel 284/784
# Training model for pixel 285/784
# Training model for pixel 286/784
# Training model for pixel 287/784
# Training model for pixel 288/784
# Training model for pixel 289/784
# Training model for pixel 290/784
# Training model for pixel 291/784
# Training model for pixel 292/784
# Training model for pixel 293/784
# Training model for pixel 294/784
# Training model for pixel 295/784
# Training model for pixel 296/784
# Training model for pixel 297/784
# Training model for pixel 298/784
# Training model for pixel 299/784
# Training model for pixel 300/784
# Training model for pixel 301/784
# Training model for pixel 302/784
# Training model for pixel 303/784
# Training model for pixel 304/784
# Training model for pixel 305/784
# Training model for pixel 306/784
# Training model for pixel 307/784
# Training model for pixel 308/784
# Training model for pixel 309/784
# Training model for pixel 310/784
# Training model for pixel 311/784
# Training model for pixel 312/784
# Training model for pixel 313/784
# Training model for pixel 314/784
# Training model for pixel 315/784
# Training model for pixel 316/784
# Training model for pixel 317/784
# Training model for pixel 318/784
# Training model for pixel 319/784
# Training model for pixel 320/784
# Training model for pixel 321/784
# Training model for pixel 322/784
# Training model for pixel 323/784
# Training model for pixel 324/784
# Training model for pixel 325/784
# Training model for pixel 326/784
# Training model for pixel 327/784
# Training model for pixel 328/784
# Training model for pixel 329/784
# Training model for pixel 330/784
# Training model for pixel 331/784
# Training model for pixel 332/784
# Training model for pixel 333/784
# Training model for pixel 334/784
# Training model for pixel 335/784
# Training model for pixel 336/784
# Training model for pixel 337/784
# Training model for pixel 338/784
# Training model for pixel 339/784
# Training model for pixel 340/784
# Training model for pixel 341/784
# Training model for pixel 342/784
# Training model for pixel 343/784
# Training model for pixel 344/784
# Training model for pixel 345/784
# Training model for pixel 346/784
# Training model for pixel 347/784
# Training model for pixel 348/784
# Training model for pixel 349/784
# Training model for pixel 350/784
# Training model for pixel 351/784
# Training model for pixel 352/784
# Training model for pixel 353/784
# Training model for pixel 354/784
# Training model for pixel 355/784
# Training model for pixel 356/784
# Training model for pixel 357/784
# Training model for pixel 358/784
# Training model for pixel 359/784
# Training model for pixel 360/784
# Training model for pixel 361/784
# Training model for pixel 362/784
# Training model for pixel 363/784
# Training model for pixel 364/784
# Training model for pixel 365/784
# Training model for pixel 366/784
# Training model for pixel 367/784
# Training model for pixel 368/784
# Training model for pixel 369/784
# Training model for pixel 370/784
# Training model for pixel 371/784
# Training model for pixel 372/784
# Training model for pixel 373/784
# Training model for pixel 374/784
# Training model for pixel 375/784
# Training model for pixel 376/784
# Training model for pixel 377/784
# Training model for pixel 378/784
# Training model for pixel 379/784
# Training model for pixel 380/784
# Training model for pixel 381/784
# Training model for pixel 382/784
# Training model for pixel 383/784
# Training model for pixel 384/784
# Training model for pixel 385/784
# Training model for pixel 386/784
# Training model for pixel 387/784
# Training model for pixel 388/784
# Training model for pixel 389/784
# Training model for pixel 390/784
# Training model for pixel 391/784
# Training model for pixel 392/784
# Training model for pixel 393/784
# Training model for pixel 394/784
# Training model for pixel 395/784
# Training model for pixel 396/784
# Training model for pixel 397/784
# Training model for pixel 398/784
# Training model for pixel 399/784
# Training model for pixel 400/784
# Training model for pixel 401/784
# Training model for pixel 402/784
# Training model for pixel 403/784
# Training model for pixel 404/784
# Training model for pixel 405/784
# Training model for pixel 406/784
# Training model for pixel 407/784
# Training model for pixel 408/784
# Training model for pixel 409/784
# Training model for pixel 410/784
# Training model for pixel 411/784
# Training model for pixel 412/784
# Training model for pixel 413/784
# Training model for pixel 414/784
# Training model for pixel 415/784
# Training model for pixel 416/784
# Training model for pixel 417/784
# Training model for pixel 418/784
# Training model for pixel 419/784
# Training model for pixel 420/784
# Training model for pixel 421/784
# Training model for pixel 422/784
# Training model for pixel 423/784
# Training model for pixel 424/784
# Training model for pixel 425/784
# Training model for pixel 426/784
# Training model for pixel 427/784
# Training model for pixel 428/784
# Training model for pixel 429/784
# Training model for pixel 430/784
# Training model for pixel 431/784
# Training model for pixel 432/784
# Training model for pixel 433/784
# Training model for pixel 434/784
# Training model for pixel 435/784
# Training model for pixel 436/784
# Training model for pixel 437/784
# Training model for pixel 438/784
# Training model for pixel 439/784
# Training model for pixel 440/784
# Training model for pixel 441/784
# Training model for pixel 442/784
# Training model for pixel 443/784
# Training model for pixel 444/784
# Training model for pixel 445/784
# Training model for pixel 446/784
# Training model for pixel 447/784
# Training model for pixel 448/784
# Training model for pixel 449/784
# Training model for pixel 450/784
# Training model for pixel 451/784
# Training model for pixel 452/784
# Training model for pixel 453/784
# Training model for pixel 454/784
# Training model for pixel 455/784
# Training model for pixel 456/784
# Training model for pixel 457/784
# Training model for pixel 458/784
# Training model for pixel 459/784
# Training model for pixel 460/784
# Training model for pixel 461/784
# Training model for pixel 462/784
# Training model for pixel 463/784
# Training model for pixel 464/784
# Training model for pixel 465/784
# Training model for pixel 466/784
# Training model for pixel 467/784
# Training model for pixel 468/784
# Training model for pixel 469/784
# Training model for pixel 470/784
# Training model for pixel 471/784
# Training model for pixel 472/784
# Training model for pixel 473/784
# Training model for pixel 474/784
# Training model for pixel 475/784
# Training model for pixel 476/784
# Training model for pixel 477/784
# Training model for pixel 478/784
# Training model for pixel 479/784
# Training model for pixel 480/784
# Training model for pixel 481/784
# Training model for pixel 482/784
# Training model for pixel 483/784
# Training model for pixel 484/784
# Training model for pixel 485/784
# Training model for pixel 486/784
# Training model for pixel 487/784
# Training model for pixel 488/784
# Training model for pixel 489/784
# Training model for pixel 490/784
# Training model for pixel 491/784
# Training model for pixel 492/784
# Training model for pixel 493/784
# Training model for pixel 494/784
# Training model for pixel 495/784
# Training model for pixel 496/784
# Training model for pixel 497/784
# Training model for pixel 498/784
# Training model for pixel 499/784
# Training model for pixel 500/784
# Training model for pixel 501/784
# Training model for pixel 502/784
# Training model for pixel 503/784
# Training model for pixel 504/784
# Training model for pixel 505/784
# Training model for pixel 506/784
# Training model for pixel 507/784
# Training model for pixel 508/784
# Training model for pixel 509/784
# Training model for pixel 510/784
# Training model for pixel 511/784
# Training model for pixel 512/784
# Training model for pixel 513/784
# Training model for pixel 514/784
# Training model for pixel 515/784
# Training model for pixel 516/784
# Training model for pixel 517/784
# Training model for pixel 518/784
# Training model for pixel 519/784
# Training model for pixel 520/784
# Training model for pixel 521/784
# Training model for pixel 522/784
# Training model for pixel 523/784
# Training model for pixel 524/784
# Training model for pixel 525/784
# Training model for pixel 526/784
# Training model for pixel 527/784
# Training model for pixel 528/784
# Training model for pixel 529/784
# Training model for pixel 530/784
# Training model for pixel 531/784
# Training model for pixel 532/784
# Training model for pixel 533/784
# Training model for pixel 534/784
# Training model for pixel 535/784
# Training model for pixel 536/784
# Training model for pixel 537/784
# Training model for pixel 538/784
# Training model for pixel 539/784
# Training model for pixel 540/784
# Training model for pixel 541/784
# Training model for pixel 542/784
# Training model for pixel 543/784
# Training model for pixel 544/784
# Training model for pixel 545/784
# Training model for pixel 546/784
# Training model for pixel 547/784
# Training model for pixel 548/784
# Training model for pixel 549/784
# Training model for pixel 550/784
# Training model for pixel 551/784
# Training model for pixel 552/784
# Training model for pixel 553/784
# Training model for pixel 554/784
# Training model for pixel 555/784
# Training model for pixel 556/784
# Training model for pixel 557/784
# Training model for pixel 558/784
# Training model for pixel 559/784
# Training model for pixel 560/784
# Training model for pixel 561/784
# Training model for pixel 562/784
# Training model for pixel 563/784
# Training model for pixel 564/784
# Training model for pixel 565/784
# Training model for pixel 566/784
# Training model for pixel 567/784
# Training model for pixel 568/784
# Training model for pixel 569/784
# Training model for pixel 570/784
# Training model for pixel 571/784
# Training model for pixel 572/784
# Training model for pixel 573/784
# Training model for pixel 574/784
# Training model for pixel 575/784
# Training model for pixel 576/784
# Training model for pixel 577/784
# Training model for pixel 578/784
# Training model for pixel 579/784
# Training model for pixel 580/784
# Training model for pixel 581/784
# Training model for pixel 582/784
# Training model for pixel 583/784
# Training model for pixel 584/784
# Training model for pixel 585/784
# Training model for pixel 586/784
# Training model for pixel 587/784
# Training model for pixel 588/784
# Training model for pixel 589/784
# Training model for pixel 590/784
# Training model for pixel 591/784
# Training model for pixel 592/784
# Training model for pixel 593/784
# Training model for pixel 594/784
# Training model for pixel 595/784
# Training model for pixel 596/784
# Training model for pixel 597/784
# Training model for pixel 598/784
# Training model for pixel 599/784
# Training model for pixel 600/784
# Training model for pixel 601/784
# Training model for pixel 602/784
# Training model for pixel 603/784
# Training model for pixel 604/784
# Training model for pixel 605/784
# Training model for pixel 606/784
# Training model for pixel 607/784
# Training model for pixel 608/784
# Training model for pixel 609/784
# Training model for pixel 610/784
# Training model for pixel 611/784
# Training model for pixel 612/784
# Training model for pixel 613/784
# Training model for pixel 614/784
# Training model for pixel 615/784
# Training model for pixel 616/784
# Training model for pixel 617/784
# Training model for pixel 618/784
# Training model for pixel 619/784
# Training model for pixel 620/784
# Training model for pixel 621/784
# Training model for pixel 622/784
# Training model for pixel 623/784
# Training model for pixel 624/784
# Training model for pixel 625/784
# Training model for pixel 626/784
# Training model for pixel 627/784
# Training model for pixel 628/784
# Training model for pixel 629/784
# Training model for pixel 630/784
# Training model for pixel 631/784
# Training model for pixel 632/784
# Training model for pixel 633/784
# Training model for pixel 634/784
# Training model for pixel 635/784
# Training model for pixel 636/784
# Training model for pixel 637/784
# Training model for pixel 638/784
# Training model for pixel 639/784
# Training model for pixel 640/784
# Training model for pixel 641/784
# Training model for pixel 642/784
# Training model for pixel 643/784
# Training model for pixel 644/784
# Training model for pixel 645/784
# Training model for pixel 646/784
# Training model for pixel 647/784
# Training model for pixel 648/784
# Training model for pixel 649/784
# Training model for pixel 650/784
# Training model for pixel 651/784
# Training model for pixel 652/784
# Training model for pixel 653/784
# Training model for pixel 654/784
# Training model for pixel 655/784
# Training model for pixel 656/784
# Training model for pixel 657/784
# Training model for pixel 658/784
# Training model for pixel 659/784
# Training model for pixel 660/784
# Training model for pixel 661/784
# Training model for pixel 662/784
# Training model for pixel 663/784
# Training model for pixel 664/784
# Training model for pixel 665/784
# Training model for pixel 666/784
# Training model for pixel 667/784
# Training model for pixel 668/784
# Training model for pixel 669/784
# Training model for pixel 670/784
# Training model for pixel 671/784
# Training model for pixel 672/784
# Training model for pixel 673/784
# Training model for pixel 674/784
# Training model for pixel 675/784
# Training model for pixel 676/784
# Training model for pixel 677/784
# Training model for pixel 678/784
# Training model for pixel 679/784
# Training model for pixel 680/784
# Training model for pixel 681/784
# Training model for pixel 682/784
# Training model for pixel 683/784
# Training model for pixel 684/784
# Training model for pixel 685/784
# Training model for pixel 686/784
# Training model for pixel 687/784
# Training model for pixel 688/784
# Training model for pixel 689/784
# Training model for pixel 690/784
# Training model for pixel 691/784
# Training model for pixel 692/784
# Training model for pixel 693/784
# Training model for pixel 694/784
# Training model for pixel 695/784
# Training model for pixel 696/784
# Training model for pixel 697/784
# Training model for pixel 698/784
# Training model for pixel 699/784
# Training model for pixel 700/784
# Training model for pixel 701/784
# Training model for pixel 702/784
# Training model for pixel 703/784
# Training model for pixel 704/784
# Training model for pixel 705/784
# Training model for pixel 706/784
# Training model for pixel 707/784
# Training model for pixel 708/784
# Training model for pixel 709/784
# Training model for pixel 710/784
# Training model for pixel 711/784
# Training model for pixel 712/784
# Training model for pixel 713/784
# Training model for pixel 714/784
# Training model for pixel 715/784
# Training model for pixel 716/784
# Training model for pixel 717/784
# Training model for pixel 718/784
# Training model for pixel 719/784
# Training model for pixel 720/784
# Training model for pixel 721/784
# Training model for pixel 722/784
# Training model for pixel 723/784
# Training model for pixel 724/784
# Training model for pixel 725/784
# Training model for pixel 726/784
# Training model for pixel 727/784
# Training model for pixel 728/784
# Training model for pixel 729/784
# Training model for pixel 730/784
# Training model for pixel 731/784
# Training model for pixel 732/784
# Training model for pixel 733/784
# Training model for pixel 734/784
# Training model for pixel 735/784
# Training model for pixel 736/784
# Training model for pixel 737/784
# Training model for pixel 738/784
# Training model for pixel 739/784
# Training model for pixel 740/784
# Training model for pixel 741/784
# Training model for pixel 742/784
# Training model for pixel 743/784
# Training model for pixel 744/784
# Training model for pixel 745/784
# Training model for pixel 746/784
# Training model for pixel 747/784
# Training model for pixel 748/784
# Training model for pixel 749/784
# Training model for pixel 750/784
# Training model for pixel 751/784
# Training model for pixel 752/784
# Training model for pixel 753/784
# Training model for pixel 754/784
# Training model for pixel 755/784
# Training model for pixel 756/784
# Training model for pixel 757/784
# Training model for pixel 758/784
# Training model for pixel 759/784
# Training model for pixel 760/784
# Training model for pixel 761/784
# Training model for pixel 762/784
# Training model for pixel 763/784
# Training model for pixel 764/784
# Training model for pixel 765/784
# Training model for pixel 766/784
# Training model for pixel 767/784
# Training model for pixel 768/784
# Training model for pixel 769/784
# Training model for pixel 770/784
# Training model for pixel 771/784
# Training model for pixel 772/784
# Training model for pixel 773/784
# Training model for pixel 774/784
# Training model for pixel 775/784
# Training model for pixel 776/784
# Training model for pixel 777/784
# Training model for pixel 778/784
# Training model for pixel 779/784
# Training model for pixel 780/784
# Training model for pixel 781/784
# Training model for pixel 782/784
# Training model for pixel 783/784
# Training model for pixel 784/784

# %%
# Generate a new image
# Start with a random image or the mean image; here we use a random one
new_image = np.random.rand(1, X_train_5.shape[1])
for _ in range(10):  # Iterate to refine the image
    for i, model in enumerate(models):
        X_gen = np.delete(new_image, i, axis=1)
        new_image[:, i] = model.predict(X_gen)

    # Transform the generated image back to the original space
    print_image = scaler.inverse_transform(new_image)

    # Plot the generated image
    plt.imshow(print_image.reshape(28, 28), cmap='gray')
    plt.title("Generated Image of Digit 5")
    plt.show()
